# %% [markdown]
# # Introduction
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# **What?** Introduction to Pandas object types

# %% [markdown]
# # Pandas Object Types
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - `DataFrame` is a class designed to efficiently handle data in tabular form, i.e., data characterized by a columnar organiza‐ tion. To this end, the DataFrame class provides, for instance, column labeling as well as flexible indexing capabilities for the rows (records) of the data set, similar to a table in a relational database or an Excel spreadsheet
#
# - `Series` class of pandas, which in a sense rep‐ resents a special case of the `DataFrame` class with a single column of data only. A Series object is obtained when a single column is selected from a multicolumn `DataFrame` object.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Imports
# <hr style = "border:2px solid black" ></hr>

# %%
import pandas as pd

# %% [markdown]
# # DataFrame Class
# <hr style = "border:2px solid black" ></hr>

# %%
df = pd.DataFrame([10, 20, 30, 40],  
                  columns=['numbers'],  
                  index=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['numbers'], dtype='object')

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc[['a', 'd']]
# Out:
#    numbers
# a       10
# d       40

# %%
df.iloc[1:3]
# Out:
#    numbers
# b       20
# c       30

# %%
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x: x ** 2)
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df ** 2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df['floats'] = (1.5, 2.5, 3.5, 4.5)

# %%
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
df['floats']
# Out:
# a    1.5
# b    2.5
# c    3.5
# d    4.5
# Name: floats, dtype: float64

# %%
df['names'] = pd.DataFrame(['Yves', 'Sandra', 'Lilli', 'Henry'],
                           index=['d', 'a', 'b', 'c'])

# %%
df
# Out:
#    numbers  floats   names
# a       10     1.5  Sandra
# b       20     2.5   Lilli
# c       30     3.5   Henry
# d       40     4.5    Yves

# %%
df.append({'numbers': 100, 'floats': 5.75, 'names': 'Jil'},
               ignore_index=True)
# Out:
# /var/folders/5x/lyqr8wv507n43bnwpsz4dq_c0000gn/T/ipykernel_18816/853266925.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'numbers': 100, 'floats': 5.75, 'names': 'Jil'},
#    numbers  floats   names
# 0       10    1.50  Sandra
# 1       20    2.50   Lilli
# 2       30    3.50   Henry
# 3       40    4.50    Yves
# 4      100    5.75     Jil

# %%
df = df.append(pd.DataFrame({'numbers': 100, 'floats': 5.75,
                             'names': 'Jil'}, index=['y',]))
# Out:
# /var/folders/5x/lyqr8wv507n43bnwpsz4dq_c0000gn/T/ipykernel_18816/1208231708.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({'numbers': 100, 'floats': 5.75,

# %%
df
# Out:
#    numbers  floats   names
# a       10    1.50  Sandra
# b       20    2.50   Lilli
# c       30    3.50   Henry
# d       40    4.50    Yves
# y      100    5.75     Jil

# %%
df = df.append(pd.DataFrame({'names': 'Liz'}, index=['z',]), sort=False)
# Out:
# /var/folders/5x/lyqr8wv507n43bnwpsz4dq_c0000gn/T/ipykernel_18816/2920860863.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({'names': 'Liz'}, index=['z',]), sort=False)

# %%
df
# Out:
#    numbers  floats   names
# a     10.0    1.50  Sandra
# b     20.0    2.50   Lilli
# c     30.0    3.50   Henry
# d     40.0    4.50    Yves
# y    100.0    5.75     Jil
# z      NaN     NaN     Liz

# %%
df.dtypes
# Out:
# numbers    float64
# floats     float64
# names       object
# dtype: object

# %%
df[['numbers', 'floats']].mean()
# Out:
# numbers    40.00
# floats      3.55
# dtype: float64

# %%
df[['numbers', 'floats']].std()
# Out:
# numbers    35.355339
# floats      1.662077
# dtype: float64

# %% [markdown]
# # Basic Analytics

# %%
import numpy as np

# %%
np.random.seed(100)

# %%
a = np.random.standard_normal((9, 4))

# %%
a
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
a = np.random.standard_normal((9, 4))
df = pd.DataFrame(a)

# %%
df
# Out:
#           0         1         2         3
# 0  1.189622 -1.690617 -1.356399 -1.232435
# 1 -0.544439 -0.668172  0.007315 -0.612939
# 2  1.299748 -1.733096 -0.983310  0.357508
# 3 -1.613579  1.470714 -1.188018 -0.549746
# 4 -0.940046 -0.827932  0.108863  0.507810
# 5 -0.862227  1.249470 -0.079611 -0.889731
# 6 -0.881798  0.018639  0.237845  0.013549
# 7 -1.635529 -1.044210  0.613039  0.736205
# 8  1.026921 -1.432191 -1.841188  0.366093

# %%
df.columns = ['No1', 'No2', 'No3', 'No4']

# %%
df
# Out:
#         No1       No2       No3       No4
# 0  1.189622 -1.690617 -1.356399 -1.232435
# 1 -0.544439 -0.668172  0.007315 -0.612939
# 2  1.299748 -1.733096 -0.983310  0.357508
# 3 -1.613579  1.470714 -1.188018 -0.549746
# 4 -0.940046 -0.827932  0.108863  0.507810
# 5 -0.862227  1.249470 -0.079611 -0.889731
# 6 -0.881798  0.018639  0.237845  0.013549
# 7 -1.635529 -1.044210  0.613039  0.736205
# 8  1.026921 -1.432191 -1.841188  0.366093

# %%
df['No2'].mean()
# Out:
# -0.5174882756841399

# %%
dates = pd.date_range('2019-1-1', periods=9, freq='M')

# %%
dates
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.index = dates

# %%
df
# Out:
#                  No1       No2       No3       No4
# 2019-01-31  1.189622 -1.690617 -1.356399 -1.232435
# 2019-02-28 -0.544439 -0.668172  0.007315 -0.612939
# 2019-03-31  1.299748 -1.733096 -0.983310  0.357508
# 2019-04-30 -1.613579  1.470714 -1.188018 -0.549746
# 2019-05-31 -0.940046 -0.827932  0.108863  0.507810
# 2019-06-30 -0.862227  1.249470 -0.079611 -0.889731
# 2019-07-31 -0.881798  0.018639  0.237845  0.013549
# 2019-08-31 -1.635529 -1.044210  0.613039  0.736205
# 2019-09-30  1.026921 -1.432191 -1.841188  0.366093

# %%
df.values
# Out:
# array([[ 1.18962227, -1.69061683, -1.35639905, -1.23243451],
#        [-0.54443916, -0.66817174,  0.00731456, -0.61293874],
#        [ 1.29974807, -1.73309562, -0.9833101 ,  0.35750775],
#        [-1.6135785 ,  1.47071387, -1.1880176 , -0.54974619],
#        [-0.94004616, -0.82793236,  0.10886347,  0.50780959],
#        [-0.86222735,  1.24946974, -0.07961125, -0.88973148],
#        [-0.88179839,  0.01863895,  0.23784462,  0.01354855],
#        [-1.6355294 , -1.04420988,  0.61303888,  0.73620521],
#        [ 1.02692144, -1.43219061, -1.8411883 ,  0.36609323]])

# %%
np.array(df)
# Out:
# array([[ 1.18962227, -1.69061683, -1.35639905, -1.23243451],
#        [-0.54443916, -0.66817174,  0.00731456, -0.61293874],
#        [ 1.29974807, -1.73309562, -0.9833101 ,  0.35750775],
#        [-1.6135785 ,  1.47071387, -1.1880176 , -0.54974619],
#        [-0.94004616, -0.82793236,  0.10886347,  0.50780959],
#        [-0.86222735,  1.24946974, -0.07961125, -0.88973148],
#        [-0.88179839,  0.01863895,  0.23784462,  0.01354855],
#        [-1.6355294 , -1.04420988,  0.61303888,  0.73620521],
#        [ 1.02692144, -1.43219061, -1.8411883 ,  0.36609323]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9 entries, 2019-01-31 to 2019-09-30
# Freq: M
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No1     9 non-null      float64
#  1   No2     9 non-null      float64
#  2   No3     9 non-null      float64
#  3   No4     9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0 bytes

# %%
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean  -0.329036 -0.517488 -0.497941 -0.144854
# std    1.181335  1.196330  0.853464  0.694755
# min   -1.635529 -1.733096 -1.841188 -1.232435
# 25%   -0.940046 -1.432191 -1.188018 -0.612939
# 50%   -0.862227 -0.827932 -0.079611  0.013549
# 75%    1.026921  0.018639  0.108863  0.366093
# max    1.299748  1.470714  0.613039  0.736205

# %%
df.sum()
# Out:
# No1   -2.961327
# No2   -4.657394
# No3   -4.481465
# No4   -1.303687
# dtype: float64

# %%
df.mean()
# Out:
# No1   -0.329036
# No2   -0.517488
# No3   -0.497941
# No4   -0.144854
# dtype: float64

# %%
df.mean(axis=0)
# Out:
# No1   -0.329036
# No2   -0.517488
# No3   -0.497941
# No4   -0.144854
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2019-01-31   -0.772457
# 2019-02-28   -0.454559
# 2019-03-31   -0.264787
# 2019-04-30   -0.470157
# 2019-05-31   -0.287826
# 2019-06-30   -0.145525
# 2019-07-31   -0.152942
# 2019-08-31   -0.332624
# 2019-09-30   -0.470091
# Freq: M, dtype: float64

# %%
df.cumsum()
# Out:
#                  No1       No2       No3       No4
# 2019-01-31  1.189622 -1.690617 -1.356399 -1.232435
# 2019-02-28  0.645183 -2.358789 -1.349084 -1.845373
# 2019-03-31  1.944931 -4.091884 -2.332395 -1.487865
# 2019-04-30  0.331353 -2.621170 -3.520412 -2.037612
# 2019-05-31 -0.608693 -3.449103 -3.411549 -1.529802
# 2019-06-30 -1.470921 -2.199633 -3.491160 -2.419534
# 2019-07-31 -2.352719 -2.180994 -3.253315 -2.405985
# 2019-08-31 -3.988249 -3.225204 -2.640276 -1.669780
# 2019-09-30 -2.961327 -4.657394 -4.481465 -1.303687

# %%
np.mean(df)
# Out:
# /opt/anaconda3/envs/trainingAI/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# No1   -0.329036
# No2   -0.517488
# No3   -0.497941
# No4   -0.144854
# dtype: float64

# %%
# raises warning
np.log(df)
# Out:
# /opt/anaconda3/envs/trainingAI/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#                  No1       No2       No3       No4
# 2019-01-31  0.173636       NaN       NaN       NaN
# 2019-02-28       NaN       NaN -4.917888       NaN
# 2019-03-31  0.262170       NaN       NaN -1.028598
# 2019-04-30       NaN  0.385748       NaN       NaN
# 2019-05-31       NaN       NaN -2.217661 -0.677649
# 2019-06-30       NaN  0.222719       NaN       NaN
# 2019-07-31       NaN -3.982502 -1.436138 -4.301476
# 2019-08-31       NaN       NaN -0.489327 -0.306246
# 2019-09-30  0.026565       NaN       NaN -1.004867

# %%
np.sqrt(abs(df))
# Out:
#                  No1       No2       No3       No4
# 2019-01-31  1.090698  1.300237  1.164645  1.110151
# 2019-02-28  0.737861  0.817418  0.085525  0.782904
# 2019-03-31  1.140065  1.316471  0.991620  0.597920
# 2019-04-30  1.270267  1.212730  1.089962  0.741449
# 2019-05-31  0.969560  0.909908  0.329945  0.712608
# 2019-06-30  0.928562  1.117797  0.282155  0.943256
# 2019-07-31  0.939041  0.136525  0.487693  0.116398
# 2019-08-31  1.278878  1.021866  0.782968  0.858024
# 2019-09-30  1.013371  1.196742  1.356904  0.605056

# %%
np.sqrt(abs(df)).sum()
# Out:
# No1    9.368304
# No2    9.029693
# No3    6.571417
# No4    6.467765
# dtype: float64

# %%
100 * df + 100
# Out:
#                    No1         No2         No3         No4
# 2019-01-31  218.962227  -69.061683  -35.639905  -23.243451
# 2019-02-28   45.556084   33.182826  100.731456   38.706126
# 2019-03-31  229.974807  -73.309562    1.668990  135.750775
# 2019-04-30  -61.357850  247.071387  -18.801760   45.025381
# 2019-05-31    5.995384   17.206764  110.886347  150.780959
# 2019-06-30   13.777265  224.946974   92.038875   11.026852
# 2019-07-31   11.820161  101.863895  123.784462  101.354855
# 2019-08-31  -63.552940   -4.420988  161.303888  173.620521
# 2019-09-30  202.692144  -43.219061  -84.118830  136.609323

# %% [markdown]
# # Series Class
# <hr style = "border:2px solid black" ></hr>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
S = pd.Series(np.linspace(0, 15, 7), name='series')

# %%
S
# Out:
# 0     0.0
# 1     2.5
# 2     5.0
# 3     7.5
# 4    10.0
# 5    12.5
# 6    15.0
# Name: series, dtype: float64

# %%
type(S)
# Out:
# pandas.core.series.Series

# %%
s = df['No1']

# %%
s
# Out:
# 2019-01-31    1.189622
# 2019-02-28   -0.544439
# 2019-03-31    1.299748
# 2019-04-30   -1.613579
# 2019-05-31   -0.940046
# 2019-06-30   -0.862227
# 2019-07-31   -0.881798
# 2019-08-31   -1.635529
# 2019-09-30    1.026921
# Freq: M, Name: No1, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# -0.32903635324772246

# %%
s.plot(lw=2.0, figsize=(10, 6));
# plt.savefig('../../images/ch05/pd_plot_03.png')

# %% [markdown]
# # Conclusions
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - `DataFrame` class is particularly suited to working with tabular data of any kind.
# - Most operations on such objects are vectorized, leading not only—as in the `NumPy` case—to concise code but also to high performance in general.
# - In addition, pandas makes working with incomplete data sets convenient (which is not the case with `NumPy`, for instance).

# %% [markdown]
# # References
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - https://github.com/yhilpisch/py4fi2nd/blob/master/code/ch05/05_pandas.ipynb

# %% [markdown]
# # Requirements
# <hr style = "border:2px solid black" ></hr>

# %%
# %load_ext watermark
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.29.0
#
# autopep8: 1.6.0
# json    : 2.0.9
# numpy   : 1.22.2
# pandas  : 1.4.0
